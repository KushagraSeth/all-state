# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns

# %%
filename1='test.csv'
filename2='train.csv'
df1=pd.read_csv(filename1)
df2=pd.read_csv(filename2)

# %%
df1.head(10) # displaying first 10 rows of test case
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5     cont6  \
# 0   4    A    B    A    A    A    A    A    A    B  ...  0.281143  0.466591
# 1   6    A    B    A    B    A    A    A    A    B  ...  0.836443  0.482425
# 2   9    A    B    A    B    B    A    B    A    B  ...  0.718531  0.212308
# 3  12    A    A    A    A    B    A    A    A    A  ...  0.397069  0.369930
# 4  15    B    A    A    A    A    B    A    A    A  ...  0.302678  0.398862
# 5  17    A    A    A    A    B    A    A    A    A  ...  0.643315  0.407351
# 6  21    B    A    A    A    B    B    A    A    A  ...  0.281143  0.960845
# 7  28    B    B    A    A    A    A    A    A    B  ...  0.651246  0.451115
# 8  32    A    B    A    A    A    A    A    A    B  ...  0.534484  0.343492
# 9  43    A    B    A    A    A    A    A    A    B  ...  0.281143  0.394921
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13    cont14
# ...

# %%
df2.head(10)
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   1    A    B    A    B    A    A    A    A    B  ...  0.718367  0.335060
# 1   2    A    B    A    A    A    A    A    A    B  ...  0.438917  0.436585
# 2   5    A    B    A    A    B    A    A    A    B  ...  0.289648  0.315545
# 3  10    B    B    A    B    A    A    A    A    B  ...  0.440945  0.391128
# 4  11    A    B    A    B    A    A    A    A    B  ...  0.178193  0.247408
# 5  13    A    B    A    A    A    A    A    A    B  ...  0.364464  0.401162
# 6  14    A    A    A    A    B    A    A    A    A  ...  0.381515  0.363768
# 7  20    A    B    A    B    A    A    A    A    B  ...  0.867021  0.583389
# 8  23    A    B    B    B    B    A    A    A    B  ...  0.628534  0.384099
# 9  24    A    B    A    A    B    B    A    A    B  ...  0.713343  0.469223
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14      loss
# ...

# %%
df1.describe()
# Out:
#                   id          cont1          cont2          cont3  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean   294067.153442       0.494447       0.506939       0.498255
# std    170098.335649       0.187961       0.206837       0.201746
# min         4.000000       0.000016       0.001149       0.002634
# 25%    146414.250000       0.347403       0.358319       0.336963
# 50%    294306.000000       0.475784       0.555782       0.527991
# 75%    441800.000000       0.626630       0.681761       0.634224
# max    587634.000000       0.984975       0.862654       0.944251
#
#                cont4          cont5          cont6          cont7  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean        0.492334       0.487640       0.492188       0.485945
# std         0.210815       0.209119       0.205574       0.178650
# min         0.176921       0.281143       0.012683       0.069503
# ...

# %%
df1.dtypes # checking types of variable in test dataset
# Out:
# id          int64
# cat1       object
# cat2       object
# cat3       object
# cat4       object
#            ...
# cont10    float64
# cont11    float64
# cont12    float64
# cont13    float64
# cont14    float64
# Length: 131, dtype: object

# %%
dataset = pd.get_dummies(df2)
datasetTest = pd.get_dummies(df1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188318 entries, 0 to 188317
# Columns: 1155 entries, id to cat116_Y
# dtypes: float64(15), int64(1), uint8(1139)
# memory usage: 227.5 MB

# %%
crc = dataset.corrwith(dataset['loss'])

# %%
crc[~crc.between(-.5,.5,)].index
# Out:
# Index(['loss'], dtype='object')

# %%
datasetTrain = dataset[['cat1_A', 'cat1_B', 'cat2_A', 'cat2_B', 'cat7_A', 'cat7_B',
       'cat9_A', 'cat9_B', 'cat10_A', 'cat10_B', 'cat11_A', 'cat11_B',
       'cat12_A', 'cat12_B', 'cat13_A', 'cat13_B', 'cat57_A', 'cat57_B',
       'cat72_A', 'cat72_B', 'cat79_B', 'cat79_D', 'cat80_B', 'cat80_D',
       'cat81_B', 'cat81_D', 'cat87_B', 'cat87_C', 'cat87_D', 'cat89_A',
       'cat89_B', 'cat101_A','loss', ]]

datasetTest = datasetTest[['cat1_A', 'cat1_B', 'cat2_A', 'cat2_B', 'cat7_A', 'cat7_B',
       'cat9_A', 'cat9_B', 'cat10_A', 'cat10_B', 'cat11_A', 'cat11_B',
       'cat12_A', 'cat12_B', 'cat13_A', 'cat13_B', 'cat57_A', 'cat57_B',
       'cat72_A', 'cat72_B', 'cat79_B', 'cat79_D', 'cat80_B', 'cat80_D',
       'cat81_B', 'cat81_D', 'cat87_B', 'cat87_C', 'cat87_D', 'cat89_A',
       'cat89_B', 'cat101_A']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
trainX,testX,trainY,testY = train_test_split(datasetTrain.iloc[:,:-1],datasetTrain.iloc[:,-1])

# %%
lin_reg = LinearRegression()
random_forest = RandomForestRegressor(n_estimators=50)
gradBoost = GradientBoostingRegressor()
svr = SVR()
knn = KNeighborsRegressor()

# %%
lin_reg.fit(trainX,trainY)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
random_forest.fit(trainX,trainY)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=50,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
 svr.fit(trainX,trainY)
# Out:
# F:\Python\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
 knn.fit(trainX,trainY)

# %%
gradBoost.fit(trainX,trainY)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
from sklearn.metrics import r2_score

# %%
linear_score = lin_reg.score(testX,testY)
rfr_score = random_forest.score(testX,testY)
gradboost_score = gradBoost.score(testX,testY)

# %%
print(linear_score)
# Out:
# 0.38783774722818837

# %%
print(rfr_score)
# Out:
# 0.366100434480619

# %%
gradboost_score
# Out:
# 0.39484740002504154

# %%
#Scoring parameter
from sklearn.metrics import mean_absolute_error

# %%
yhat = lin_reg.predict(testX)
mae=mean_absolute_error(testY,yhat)
mae
# Out:
# 1435.675474936279

# %%
with open("submission.csv", "w") as subfile:
    subfile.write("id,loss\n")
    for i, p in enumerate(list(yhat)):
        subfile.write("%s,%s\n"%(df1['id'][i],p))
